# %% [markdown]
# ## This project will dive into the preprocessing and analysis of indident tickets submitted to the Astronomer github repository.
# ### Table of Contents <a class="anchor" id="TOC"></a>
# [Part 1: Pulling the Data](#1)<br>
# [Part 2: Preprocessing the Data](#2)<br>
# [Part 3: Descriptive Analytics](#3)
# * [3a: Volume of Tickets Over Time](#3a)
# * [3b: Isolating the Number of Unique Visitors](#3b)
# * [3c: Length of Time for a Ticket to Close](#3c)
# * [3d: Removing Outliers from Numerical Columns with Z-Score Method](#3d)
# * [[WIP] Part 4: Machine Learning (Regression to Predict Ticket Resolution Time)](#4)

# %% [markdown]
# # Part 1: Pulling the Data <a class="anchor" id="1"></a>

# %% [markdown]
# [return to TOC](#TOC)

# %%
'''
Here are some preliminary imports. We'll need more.
Feel free to install and import any packages you'd like.
'''
import requests
import os
import json
import numpy as np
import pandas as pd

# Additional Libraries
import config #to pull API secret key
from matplotlib import pyplot as plt
import datetime as dt
import seaborn as sns

# x axis ticks
import matplotlib.dates as mdates
import matplotlib.ticker as mtick

# %%
'''
Let's retrieve all issues in the Apache Airflow OSS project using the github api. 
Insert your username below (in two places).

You should end up with about 20k issues, including ones that date back to 2015 when the project was created.
'''
def get_issues_from_api():
    session = requests.Session()
    url = "https://api.github.com/repos/apache/airflow/issues?state=all"
    response = session.get(
        url,
        auth=(
            "AmirZahre", # your github username
            config.api_secret
        ),
    )
    yield response.json()

    page=2
    while 'next' in response.links:
        response = session.get(
            url,
            auth=(
                "AmirZahre", # your github username
                config.api_secret
            ),
            params={"page": page}
        )
        page += 1
        yield response.json()
        

def get_all_issues(cache_path="airflow_issues.feather"):
    if os.path.exists(cache_path):
        print("retrieving issues from cache")
        df = pd.read_feather(cache_path)
    else:
        print("retrieving issues from API")
        df_shards = []
        for i, page in enumerate(get_issues_from_api()):
            print(f"retrieving page {i}")
            if not page:
                print(f"No issues found on page {i}: {page}")
                continue
            page_df = pd.DataFrame(page)
            df_shards.append(page_df)
        df = pd.concat(df_shards).reset_index()
        print(f"Saving results to {cache_path}")
        df.to_feather(cache_path)
    return df

# %%
df = get_all_issues()
# Out:
# retrieving issues from cache

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# # Part 2: Preprocessing the Data <a class="anchor" id="2"></a>

# %% [markdown]
# [return to TOC](#TOC)

# %%
'''
For xlabel changes in a few graphs below there the x-axis is the month
'''
def getMonthName(month_number):
    testdate=dt.date(2010,int(month_number),1)
    return testdate.strftime('%b')


'''
For removing outliers in a few tables below
The following formula removes outliers (Z-score => 3) from all numeric columns.
'''
import scipy
# pulled from https://stackoverflow.com/questions/23199796/detect-and-exclude-outliers-in-a-pandas-dataframe by KeyMaker00
def drop_numerical_outliers(df1):
    # Constrains will contain `True` or `False` depending on if it is a value below the threshold.
    constrains = df1.select_dtypes(include=[np.number]) \
        .apply(lambda x: np.abs(scipy.stats.zscore(x)) < 3) \
        .all(axis=1)
    # Drop (inplace) values set to be rejected
    df1.drop(df1.index[~constrains], inplace=True)

# %%
df = df.drop(columns=['index', 'url', 'repository_url', 'labels_url', 'comments_url',
                      'events_url', 'html_url', 'performed_via_github_app', 'locked',
                      'active_lock_reason', 'assignees', 'milestone'])

# Processing timestamps
df['created_at'] = pd.to_datetime(df['created_at'], format="%Y/%m/%d")
df['closed_at'] = pd.to_datetime(df['closed_at'], format="%Y/%m/%d")

# Binarizing some features
df["has_pull_request"] = df.pull_request.apply(lambda x: True if x is not None else False)
df["has_comment"] = df.comments.apply(lambda x: True if x > 0 else False)
df['has_assignee'] = df['assignee'].apply(lambda x: True if x is not None else False)


# Binarizing some more features
df["contributor"] = df.author_association.apply(lambda x: True if x == 'CONTRIBUTOR' else False)
df["member"] = df.author_association.apply(lambda x: True if x == 'MEMBER' else False)
df["collaborator"] = df.author_association.apply(lambda x: True if x == 'COLLABORATOR' else False)
df["not_a_member"] = df.author_association.apply(lambda x: True if x == 'NONE' else False)


# Extracting the lengths of text features `title` and `body`
df = df[df.body.notnull()]
df['length_of_title'] = df['title'].apply(lambda x: len(x))
df['length_of_body'] = df['body'].apply(lambda x: len(x))

# Removing issues created by bots
df['creator_user_login'] = df['user'].apply(lambda x: x.get('login'))
df = df[df['creator_user_login'] != 'dependabot[bot]']

# %%
# Parsing the `labels` to determine the number of labels and which of the popular labels are used for each issue
df['label_names'] = df['labels'].apply(lambda x: [str(i.get('name')) for i in x])
df['n_labels'] = df['label_names'].apply(lambda x: len(x))
not_labels = df.columns.to_list()

def label_column_to_true(row):
    for label in row.label_names:
        label = (
            label     
            .replace(":", "_")
            .replace(" ", "_")
            .replace("/", "_")
            .replace("'", "")
            .replace(".", "_")
            .replace("-", "_")
        )
        row[label] = 1
    return row


df_labels = df.apply(label_column_to_true, axis=1)
df_labels = df_labels.loc[:, ~df_labels.columns.isin(not_labels)]

# Labels that are used for at least 5% of issues
df_labels_keep = df_labels.T[(df_labels.isna().sum(axis=0) < len(df_labels)*0.95)].T
df_labels_keep.fillna(0, inplace=True)
df_labels_keep = df_labels_keep.astype("bool")
df_labels_keep = df_labels_keep.add_prefix('label_')
df = df.join(df_labels_keep)

# %%
# Parsing the issue creators to identify users who create issues frequently
df['creator_user_id'] = df['user'].apply(lambda x: x.get('id'))
creators = df.creator_user_id.value_counts()

# Issues created by top 0.05% issue creators
freq_creators = dict(df.creator_user_id.value_counts(normalize=True).loc[lambda x : x>0.0005]) 
df['frequent_issue_creator'] = df.creator_user_id.apply(lambda x: x in freq_creators.keys())

# Adding and rearranging usernames and user ID's
creator_user_login = df.pop('creator_user_login')
creator_user_id = df.pop('creator_user_id')
df.insert(2, 'creator_user_login', creator_user_login)
df.insert(3, 'creator_user_id', creator_user_id)

# %%
# We now have our list of features to study
features = [
    'title',
    'creator_user_login',
    'creator_user_id',
    'body',
    'created_at',
    'state',
    'closed_at',
    'frequent_issue_creator',
    'author_association', 
    'length_of_title', 
    'length_of_body',
    'has_assignee', 
    'has_pull_request', 
    'has_comment',
    'comments',
    'contributor',
    'member',
    'collaborator',
    'not_a_member',
    'n_labels'] + list(df_labels_keep.columns)

df.drop([c for c in df if c not in features], axis=1, inplace=True)

# %% [markdown]
# ## Additional Preprocessing #2

# %%
'''
Add column for year and month of created and closed dates.
'''
df.insert(loc=5, column='created_date',value=pd.to_datetime(df.created_at.dt.strftime('%Y-%m-%d')))
df.insert(loc=6, column='closed_date',value=pd.to_datetime(df.closed_at.dt.strftime('%Y-%m-%d')))


'''
Add column for length of time, in days, for a problem to be closed from the time it was opened
'''
df.insert(loc=7, column='time_to_close', value=df.closed_date - df.created_date) # create column
df.time_to_close = df.time_to_close.apply(lambda x: x.days) # convert column to day value only (omit HH:MM:SS)
df.time_to_close = df.time_to_close.apply(lambda x: 'Not Closed' if pd.isnull(x) else int(x)) # convert values to int, NaN if NaN

'''
Set creator_user_id to type string so that it is not treated as a integer unless we require it to (we will!)
'''
df['creator_user_id'] = df['creator_user_id'].astype(str)

# %% [markdown]
# # Part 3: Descriptive Analytics <a class="anchor" id="3"></a>

# %% [markdown]
# [return to TOC](#TOC)

# %% [markdown]
# # Part 3a: Volume of Tickets Over Time <a class="anchor" id="3a"></a>
#
# [return to TOC](#TOC)
#
# Is there a trend pertaining to the number of tickets submitted? Have they been increasing, decreasing, or stagnant?
#
# It's good to know how busy things are. Are there any obvious signs of seasonality? Are things becoming busier?

# %%
'''
Group the creation date of tickets by Year and Month. Count the number of tickets for each period.
'''

# Group tickets by Year > Month
monthly_tickets = (df.groupby([df.created_date.dt.year, df.created_date.dt.month])
           .size() # Get the count of values for each period
           .rename_axis(index=['year', 'month'],)
           .reset_index())

monthly_tickets.columns.values[2] = "number_of_tickets"
monthly_tickets
# Out:
#     year  month  number_of_tickets
# 0   2015      4                  2
# 1   2015      6                 96
# 2   2015      7                111
# 3   2015      8                129
# 4   2015      9                138
# ..   ...    ...                ...
# 76  2021      9                584
# 77  2021     10                575
# 78  2021     11                473
# 79  2021     12                592
# 80  2022      1                130
#
# [81 rows x 3 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10))

# plotting for each year, by month
# years prior to, and including, 2019
years = [2015, 2016, 2017, 2018]
i = 0
for year in years:
    sub = monthly_tickets[monthly_tickets['year'] == year]
    ax.plot(sub['month'], sub['number_of_tickets'], label=year, c='black')
    i += 1

# years of 2019 to present    
years = [2019,2020, 2021]
i = 0
for year in years:
    sub = monthly_tickets[monthly_tickets['year'] == year]
    ax.plot(sub['month'], sub['number_of_tickets'], label=year)
    i += 1    

    
# x-axis ticks
# rename x-axis from month number to month name
plt.gca().xaxis.set_major_formatter(mtick.FuncFormatter(lambda x,p:getMonthName(x)))
ax.set_xticks(np.arange(1, 13, 1.0))  

# legend
ax.legend(loc="upper left")

plt.title('Volume of Issues Submitted from 2015 to Present', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.style.use('seaborn-whitegrid')     
plt.show()

# %% [markdown]
# Insights
#
# * On a month to month basis, the volume of tickets hovered at around the same levels for the years 2015 to 2018.
# * Beginning 2019, ticket volume begins to increase above historic levels.
# * 2020 is where things begin to get interesting, as ticket volume begins to substantially increase.
# * Overall, there is a substantial increase in volume for the entire periods of 2020 and 2021 vs. the years prior.
#
# How does the volume of tickets match with the number of unique visitors? Is it the same people just asking more tickets, or can this partially be attributed to a greater number of unique individuals experiencing issues?

# %% [markdown]
# # Part 3b: Isolating the Number of Unique Visitors <a class="anchor" id="3b"></a>
#
# [return to TOC](#TOC)
#
# Has there been an uptick of unique users? Are the tickets submitted by a regular group of individuals?
#
# Looking at this data can help us understand the growth of the repository as a place of knowledge for Apache Airflow.

# %%
'''
Reverse earlier code that set 'creator_user_id' to a string. 
We need to use the numbers themselves in order to organize them within a BST.
'''

df['creator_user_id'] = df['creator_user_id'].astype(int)

# %%
'''
Create a Binary Search Tree (BST).
The BST will be used to quickly and efficiently organize user ID's.
Starting from 2015 and moving towards the present, each user ID will be compared to the user ID's in the BST.
If the user ID exists, that user is **not** a unique submitter; however, if it does not exist, it's the user's first time submitting a ticket -- and therefore, they're unique.
Code pulled from https://qvault.io/python/binary-search-tree-in-python/ and https://qvault.io/python/binary-search-tree-in-python/
'''

class BSTNode:
    def __init__(self, val=None):
        self.left = None
        self.right = None
        self.val = val
        
    # Insert value into tree
    def insert(self, val):
        if not self.val:
            self.val = val
            return

        if self.val == val:
            return

        if val < self.val:
            if self.left:
                self.left.insert(val)
                return
            self.left = BSTNode(val)
            return

        if self.right:
            self.right.insert(val)
            return
        self.right = BSTNode(val)
    
    
    
    # Check if value exists in tree
    def exists(self, val):
        if self.val is None:
            return
        
        if val == self.val:
            return True

        if val < self.val:
            if self.left == None:
                return False
            return self.left.exists(val)

        if self.right == None:
            return False
        return self.right.exists(val)
    
# Print the tree in a horizontal-moving shape
def printTree(node, level=0):
    if node != None:
        printTree(node.left, level + 1)
        print(' ' * 4 * level + '->', node.val)
        printTree(node.right, level + 1)

# %%
'''
Cycle through each ID and add to the BST
If the ID exists, that will be a repeat visitor
If the ID does NOT exist, it is a unique visitor.
If it is a unique visitor, incriment +1 for the respective Month, Year
'''

# Reverse the df so that the earliest case is at the beginning
df_rev = df.iloc[::-1]

# Initialize the lists and the tree
unique_ID = []
unique_date = []
bst = BSTNode()

# For each row within the reversed df (beginning 2015)
for index, row in df_rev.iterrows():
    # If the submitter ID does NOT exist, it is assumed to be unique
    if bst.exists(row[1]) == False:
        # Therefore, append each of the tables unique_date and unique_ID with the creation date of the ticket and user ID, respectively
        unique_date.append(row[5].date())
        unique_ID.append(row[1])
    # Finally, insert the user ID into the BST so that it won't be double-counted as unique    
    bst.insert(row[1])


# Add the two lists from above into a DF
x = pd.Series(unique_date)
y = pd.Series(unique_ID)
headers = ['unique_date','unique_ID']
df_unique = pd.concat([x,y], axis=1, keys=headers)

# Return the user_ID type into a string
df['creator_user_id'] = df['creator_user_id'].astype(str)
df_unique
# Out:
#      unique_date  unique_ID
# 0     2015-06-05    1024098
# 1     2015-06-05    1329385
# 2     2015-06-05    3050855
# 3     2015-06-05    7586111
# 4     2015-06-06      57258
# ...          ...        ...
# 4222  2022-01-07   23327515
# 4223  2022-01-07   47019599
# 4224  2022-01-07   64261155
# 4225  2022-01-07   68482867
# 4226  2022-01-08   10959000
#
# [4227 rows x 2 columns]

# %%
'''
Group the creation date of tickets by Year and Month. Count the number of unique users for each period.
'''
df_unique['year'] = df_unique.unique_date.apply(lambda x: x.year)
df_unique['month'] = df_unique.unique_date.apply(lambda x: x.month)

monthly_unique = (df_unique.groupby([df_unique.year, df_unique.month])
           .size()
           .rename_axis(index=['year', 'month'],)
           .reset_index())

monthly_unique.columns.values[2] = "number_of_unique_visitors"
monthly_unique
# Out:
#     year  month  number_of_unique_visitors
# 0   2015      6                         28
# 1   2015      7                         23
# 2   2015      8                         33
# 3   2015      9                         29
# 4   2015     10                         25
# ..   ...    ...                        ...
# 75  2021      9                        126
# 76  2021     10                        135
# 77  2021     11                        109
# 78  2021     12                         88
# 79  2022      1                         21
#
# [80 rows x 3 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10))

# plotting for each year, by month
# years prior to, and including, 2019
years = [2015, 2016, 2017, 2018]
i = 0
for year in years:
    sub = monthly_unique[monthly_unique['year'] == year]
    ax.plot(sub['month'], sub['number_of_unique_visitors'], label=year, c='black')
    i += 1


# years of 2019 to present    
years = [2019,2020, 2021]
i = 0
for year in years:
    sub = monthly_unique[monthly_unique['year'] == year]
    ax.plot(sub['month'], sub['number_of_unique_visitors'], label=year)
    i += 1    
    
# x-axis ticks
plt.gca().xaxis.set_major_formatter(mtick.FuncFormatter(lambda x,p:getMonthName(x)))
ax.set_xticks(np.arange(1, 13, 1.0))  

# legend
ax.legend(loc="upper left")

plt.title('Number of Unique Accounts Submitting Issues from 2015 to Present', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.style.use('seaborn-whitegrid')    
plt.show()

# %% [markdown]
# Insights:
# * The increase in volume of tickets follows the trend of the increase of unique submitters.
# * Number of unique users held steady each year for the 2015 to 2019 period.
# * March of 2020, **something** happened to the community - the level of unique users submitting tickets rose sharply, from ~55 to ~130  users for the month of March.
# * Since that period, the levels of unique users has continued to be maintained.
# * Assumptions as to why the levels rose drastically can be due to COVID, as the pandemic also began March 2020.
#
# The reasoning behind this spike required further digging. I'd like to look into the number of enterprises utilizing Apache Airflow, as an influx of large corporations could also influence the large spike in activity from community members.

# %% [markdown]
# # Part 3c: Length of Time for a Ticket to Close <a class="anchor" id="3c"></a>
#
# [return to TOC](#TOC)

# %%
# Create a DF containing open date and number of days closed
df_days = df[['created_date','time_to_close']]

# Remove tickets that have yet to be closed
df_days = df_days[df_days['time_to_close'] != 'Not Closed']

# Changing day values to int
df_days['time_to_close'] = df_days['time_to_close'].astype(int)

df_days
# Out:
#       created_date  time_to_close
# 0       2022-01-08              0
# 2       2022-01-08              0
# 10      2022-01-07              0
# 14      2022-01-07              0
# 15      2022-01-07              0
# ...            ...            ...
# 19663   2015-06-05              2
# 19664   2015-06-05              0
# 19665   2015-06-05             12
# 19666   2015-04-20              0
# 19667   2015-04-20              0
#
# [18720 rows x 2 columns]

# %% [markdown]
# ## Outlier Detection

# %%
'''
Average number of days for a ticket to close, once opened, from 2015-present.
'''
df_days.time_to_close.mean()
# Out:
# 40.40587606837607

# %% [markdown]
# This seems awfully long (over a month). This could be due to us using the mean. Let's check the median time.

# %%
'''
Check median and mode for ticket close time (in days).
'''
from statistics import mode
print("The median is", df_days.time_to_close.median())
print("The mode is", mode(df_days.time_to_close))
# Out:
# The median is 1.0
# The mode is 0

# %% [markdown]
# This indicates a positive skew. Median number of days is one and the mode is zero, which implies that most tickets are solved fairly quickly (by the next day). The mean is, therefore, influenced by a number of outliers. Let's find and eliminate them.

# %% [markdown]
# ### Looking at outliers for the number of days a ticket has been opened.

# %% [markdown]
# The reasoning behind wanting to remove the outliers is because I'd eventually like to estimate the number of days a ticket will be completed in, based on multiple factors. The outliers here present the extreme cases of ticket completion time; hence, I'm opting to remove them.

# %%
df_days.time_to_close.value_counts()
# Out:
# 0       6644
# 1       2939
# 2       1141
# 3        710
# 4        532
#         ...
# 810        1
# 736        1
# 203        1
# 472        1
# 1733       1
# Name: time_to_close, Length: 654, dtype: int64

# %%
'''
Box plot to look at the number of days a ticket has been opened for.
It's clear that there are a lot of outliers regarding the the length of days it took for some tickets to be closed.
'''
fig, ax = plt.subplots(figsize=(10,8))
sns.boxplot(x=df_days.time_to_close)
plt.show()

# %%
df_days.time_to_close.describe()
# Out:
# count    18720.000000
# mean        40.405876
# std        144.314739
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%         14.000000
# max       1733.000000
# Name: time_to_close, dtype: float64

# %% [markdown]
# ### Removing outliers

# %%
'''
Let's run that formula from above and remove these outliers.
'''
drop_numerical_outliers(df_days)

# %%
'''
Box plot to look at the number of days a ticket has been opened for, once outliers have been removed.
'''
fig, ax = plt.subplots(figsize=(10,8))
sns.boxplot(x=df_days.time_to_close)
plt.show()

# %%
df_days.time_to_close.describe()
# Out:
# count    18420.000000
# mean        25.650977
# std         65.006554
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%         12.000000
# max        473.000000
# Name: time_to_close, dtype: float64

# %% [markdown]
# ## Analyzing Ticket Completion Time

# %%
df_days['year'] = df_days.created_date.apply(lambda x: x.year)
df_days['month'] = df_days.created_date.apply(lambda x: x.month)

# %%
monthly_ticket_time = (df_days.groupby([df_days.year, df_days.month])
           .agg(number_of_tickets=('time_to_close', 'size'), average_time_total=('time_to_close', 'mean'))
           .reset_index())


monthly_ticket_time['average_time_total'] = round(monthly_ticket_time['average_time_total'],2)
monthly_ticket_time
# Out:
#     year  month  number_of_tickets  average_time_total
# 0   2015      4                  2                0.00
# 1   2015      6                 95                6.32
# 2   2015      7                107               10.57
# 3   2015      8                121               22.46
# 4   2015      9                132               27.33
# ..   ...    ...                ...                 ...
# 76  2021      9                531                8.02
# 77  2021     10                501                9.15
# 78  2021     11                390                5.78
# 79  2021     12                474                3.46
# 80  2022      1                 86                0.55
#
# [81 rows x 4 columns]

# %%
monthly_ticket_time['date'] = pd.to_datetime(monthly_ticket_time['year'].apply(str) + ' ' + monthly_ticket_time['month'].apply(str))

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10))


monthly_ticket_time_all = monthly_ticket_time[monthly_ticket_time['year'] < 2022].copy()

# Plot the number of tickets
ax.plot(monthly_ticket_time_all['date'], monthly_ticket_time_all['number_of_tickets'], c = 'blue')
ax.set_ylabel("Number of Tickets",color="blue",fontsize=15)

# Plot the average time to complete tickets
ax2=ax.twinx()
ax2.plot(monthly_ticket_time_all['date'], monthly_ticket_time_all['average_time_total'], c = 'black')
ax2.set_ylabel("Average Time to Complete Ticket",color="black",fontsize=15)   


plt.title('Volume of Tickets vs. Completion Time, 2015-2021', fontsize=20)
plt.rcParams['font.size'] = '15'
plt.style.use('seaborn-whitegrid')    
plt.show()

# %% [markdown]
# Insights
#
# * We're able to see an interesting (and positive) trend here: although the volume of tickets held at roughly the same level for 2021, the time it took from ticket creation to completion was on the decline!
#
# This is good news -- it may imply that community engagement is increasing (quicker response times from members) and documentation/knowledge quality is improving.

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10))


x = monthly_ticket_time_all['number_of_tickets']
y = monthly_ticket_time_all['average_time_total']

plt.scatter(x, y)

plt.title('Relationship Between Number of Tickets & Average Time of Completion for Each Month, 2015 - 2021', fontsize=20)
plt.xlabel('Number of Tickets')
plt.ylabel('Average Time of Completion')

plt.show()

covariance = np.cov(x, y)
correlation = np.corrcoef(x,y)
print(covariance)
print(correlation)
# Out:
# [[33900.93101266  -126.12310127]
#  [ -126.12310127   289.3759962 ]]
# [[ 1.         -0.04026777]
#  [-0.04026777  1.        ]]

# %% [markdown]
# The covariance of the two values is negative, resting at -126.12. This suggests that the variables change in opposite directions.
#
# Does this make intuitive sense? Well, no - not really. You would expect the time for ticket completion would relate positively with the number of tickets submitted -- as in, the more tickets on the docket, the more time it will take to complete them due to an inelastic supply of resources available to solve them.
#
# The correlation of -0.04 is also very weak, which suggests that the relationship between these two variables is nearly non-existent. This helps make the negative covariance mutt, but we still have the issue where, intuitively, the covariance **should** be positive, and the correlation **should** be stronger.
#
# Let's look at a daily frequency and average, instead of monthly.

# %%
daily_ticket_time = (df_days.groupby([df_days.created_date])
           .agg(number_of_tickets=('time_to_close', 'size'), average_time_total=('time_to_close', 'mean'))
           .reset_index())

daily_ticket_time['average_time_total'] = round(daily_ticket_time['average_time_total'],2)
daily_ticket_time
# Out:
#      created_date  number_of_tickets  average_time_total
# 0      2015-04-20                  2                0.00
# 1      2015-06-05                  6                5.33
# 2      2015-06-06                  1               11.00
# 3      2015-06-07                  2                0.00
# 4      2015-06-08                  4                1.50
# ...           ...                ...                 ...
# 2233   2022-01-04                 10                0.90
# 2234   2022-01-05                 21                0.67
# 2235   2022-01-06                 20                0.20
# 2236   2022-01-07                 10                0.30
# 2237   2022-01-08                  2                0.00
#
# [2238 rows x 3 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10))


x = daily_ticket_time['number_of_tickets']
y = daily_ticket_time['average_time_total']

plt.scatter(x, y)

plt.title('Relationship Between Number of Tickets & Average Time of Completion for Each Month, 2015 - 2021', fontsize=20)
plt.xlabel('Number of Tickets')
plt.ylabel('Average Time of Completion')

plt.show()

covariance = np.cov(x, y)
correlation = np.corrcoef(x,y)
print(covariance)
print(correlation)
# Out:
# [[  56.41351341   -5.35858944]
#  [  -5.35858944 1521.29333584]]
# [[ 1.         -0.01829163]
#  [-0.01829163  1.        ]]

# %% [markdown]
# The covariance is better - kind of. It implies a negative relationship between the two, which **still** shouldn't be the case, but it's implied to be weaker.
#
# The correlation is what is most concerning. It's nearly non-existent, which leads us to believe that there really may not be much of a relationship between the two variables after all.

# %% [markdown]
# # Part 3d: Removing Outliers from Numerical Columns with Z-Score Method <a class="anchor" id="3d"></a>
#
# [return to TOC](#TOC)

# %%
df_cleaned = df.copy()

# %%
drop_numerical_outliers(df_cleaned)

# %%
df_cleaned.describe()
# Out:
#            comments  length_of_title  length_of_body      n_labels
# count  18886.000000     18886.000000    18886.000000  18886.000000
# mean       3.462035        50.322514     1367.132532      1.190088
# std        3.674687        16.716960     1144.578102      1.217766
# min        0.000000         1.000000        0.000000      0.000000
# 25%        1.000000        39.000000      648.250000      0.000000
# 50%        2.000000        50.000000     1247.000000      1.000000
# 75%        5.000000        61.000000     1700.000000      2.000000
# max       20.000000       106.000000     9642.000000      5.000000

# %% [markdown]
# Distribution before outlier removal:

# %%
fig, ax = plt.subplots(2,2, figsize=(10,8))

sns.boxplot(ax=ax[0,0], x=df.comments)
sns.boxplot(ax=ax[0,1], x=df.length_of_title)
sns.boxplot(ax=ax[1,0], x=df.length_of_body)
sns.boxplot(ax=ax[1,1], x=df.n_labels)

plt.show()

# %% [markdown]
# Distribution **after** outlier removal:

# %%
fig, ax = plt.subplots(2,2, figsize=(10,8))

sns.boxplot(ax=ax[0,0], x=df_cleaned.comments)
sns.boxplot(ax=ax[0,1], x=df_cleaned.length_of_title)
sns.boxplot(ax=ax[1,0], x=df_cleaned.length_of_body)
sns.boxplot(ax=ax[1,1], x=df_cleaned.n_labels)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,8))

x = df_cleaned.comments
y = df_cleaned.n_labels

x2 = df.comments
y2 = df.n_labels

plt.scatter(x2, y2, alpha=0.1, c='red')
plt.scatter(x, y, alpha=0.1, c='green')


plt.xlabel('Comments')
plt.ylabel('Number of Labels')
plt.show()

# %% [markdown]
# # [WIP] Part 4: Machine Learning (Regression to Predict Ticket Resolution Time)<a class="anchor" id="4"></a>

# %% [markdown]
# [return to TOC](#TOC)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from sklearn.metrics import roc_curve, roc_auc_score

# %% [markdown]
# ### We will dive into developing a model to help us predict the amount of time a ticket will be resolved based on the information available when the ticket is submitted.

# %%
'''
Now that we understand our data better, let's see if we can predict 
whether or not an issue is closed given other attributes.
Should we treat all issues created over the years the same?

We notice that the classes are not balanced. Probably a good idea to address that.

'''

df.state.value_counts()
# Out:
# closed    18720
# open        909
# Name: state, dtype: int64

# %% [markdown]
# ### Since we're looking at tickets already closed, we'll remove the ones opened.

# %%
df_ml = df_cleaned[df_cleaned['state'] == 'closed']
df_ml.state.value_counts()
# Out:
# closed    18045
# Name: state, dtype: int64

# %%
# To double check all tickets present are still open, we'll also remove any values labelled Not Closed from the time_to_close column.
df_ml = df_ml[df_ml['time_to_close'] != 'Not Closed']

# Changing day values to type int
df_ml['time_to_close'] = df_ml['time_to_close'].astype(int)

# %%
df_ml.state.value_counts()
# Out:
# closed    18045
# Name: state, dtype: int64

# %% [markdown]
# ### Tickets remaining are the ones that are closed.
#
# ### Remember the tickets that took hundreds of days to complete and were deemed as outliers earlier? Let's remove those as they aren't within the normal scope of ticket completion times.

# %%
# before outlier removal
df_ml.time_to_close.describe()
# Out:
# count    18045.000000
# mean        38.465447
# std        142.134164
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%         12.000000
# max       1733.000000
# Name: time_to_close, dtype: float64

# %%
# Removing outliers for the time_to_close column. Values with a Z-score less than 3 are kept.

u = df_ml.time_to_close.mean()
sd = df_ml.time_to_close.std()

df_ml['outlier'] = df_ml.time_to_close.apply(lambda x: abs((x-u)/sd) < 3)
df_ml = df_ml[df_ml['outlier'] == True]
df_ml
# Out:
#       creator_user_login creator_user_id  \
# 0             vinitpayal        10959000
# 2                 potiuk          595491
# 10                 kaxil         8811558
# 14           gontcharovd        49554133
# 15             subkanthi        17434846
# ...                  ...             ...
# 19663            eerwitt         1329385
# 19664            eerwitt         1329385
# 19665            osallou         1024098
# 19666       mistercrunch          487433
# 19667       mistercrunch          487433
#
#                                                    title   state  comments  \
# 0                            Rename amazon EMR hook name  closed         3
# 2      Add documentation for an ad-hoc release of 2 p...  closed         1
# 10     Bugfix: ``SFTPHook`` does not respect ``ssh_co...  closed         1
# 14                          Update manage-dags-files.rst  closed         2
# 15         Update python version to 3.7 contributing.rst  closed         0
# ...                                                  ...     ...       ...
# 19663                              Misc spelling updates  closed         3
# 19664                              setup.py download URL  closed         3
# 19665     Can't add external executors -> Plugin manager  closed        17
# 19666              Bring in more resolution to hivestats  closed         0
# 19667  Improving the search functionality in the grap...  closed         0
#
#       created_date closed_date  time_to_close                created_at  \
# 0       2022-01-08  2022-01-08              0 2022-01-08 14:15:31+00:00
# 2       2022-01-08  2022-01-08              0 2022-01-08 11:24:41+00:00
# 10      2022-01-07  2022-01-07              0 2022-01-07 19:00:53+00:00
# 14      2022-01-07  2022-01-07              0 2022-01-07 15:27:48+00:00
# 15      2022-01-07  2022-01-07              0 2022-01-07 15:04:26+00:00
# ...            ...         ...            ...                       ...
# 19663   2015-06-05  2015-06-07              2 2015-06-05 17:50:46+00:00
# 19664   2015-06-05  2015-06-05              0 2015-06-05 15:18:52+00:00
# 19665   2015-06-05  2015-06-17             12 2015-06-05 14:28:38+00:00
# 19666   2015-04-20  2015-04-20              0 2015-04-20 21:54:45+00:00
# 19667   2015-04-20  2015-04-20              0 2015-04-20 21:52:31+00:00
#
#                       closed_at author_association  \
# 0     2022-01-08 15:26:09+00:00        CONTRIBUTOR
# 2     2022-01-08 13:59:11+00:00             MEMBER
# 10    2022-01-07 21:00:17+00:00             MEMBER
# 14    2022-01-07 15:32:13+00:00               NONE
# 15    2022-01-07 15:10:21+00:00        CONTRIBUTOR
# ...                         ...                ...
# 19663 2015-06-07 07:55:22+00:00        CONTRIBUTOR
# 19664 2015-06-05 17:24:57+00:00        CONTRIBUTOR
# 19665 2015-06-17 15:41:31+00:00               NONE
# 19666 2015-04-20 22:58:48+00:00             MEMBER
# 19667 2015-04-20 21:52:33+00:00             MEMBER
#
#                                                     body  has_pull_request  \
# 0      Renamed emr hook from Elastic MapReduce to Ama...              True
# 2      <!--\r\nThank you for contributing! Please mak...              True
# 10     closes https://github.com/apache/airflow/issue...              True
# 14     Running `base64 <my-private-ssh-key> -w 0 > te...              True
# 15     Since 3.6 is no longer supported, updated mini...              True
# ...                                                  ...               ...
# 19663  I was reading over the code to understand how ...              True
# 19664  While installing I noticed the `url` and `down...             False
# 19665  Would be nice to be able to add other executor...             False
# 19666                                                                 True
# 19667                                                                 True
#
#        has_comment  has_assignee  contributor  member  collaborator  \
# 0             True         False         True   False         False
# 2             True         False        False    True         False
# 10            True         False        False    True         False
# 14            True         False        False   False         False
# 15           False         False         True   False         False
# ...            ...           ...          ...     ...           ...
# 19663         True         False         True   False         False
# 19664         True         False         True   False         False
# 19665         True         False        False   False         False
# 19666        False         False        False    True         False
# 19667        False         False        False    True         False
#
#        not_a_member  length_of_title  length_of_body  n_labels  \
# 0             False               27            1266         3
# 2             False               54            1072         4
# 10            False               57            1129         3
# 14             True               28             133         2
# 15            False               45            1160         1
# ...             ...              ...             ...       ...
# 19663         False               21             282         0
# 19664         False               21             401         0
# 19665          True               46             203         0
# 19666         False               37               0         0
# 19667         False               52               0         0
#
#        label_area_dev_tools  label_area_providers  label_area_webserver  \
# 0                     False                  True                 False
# 2                     False                  True                 False
# 10                    False                  True                 False
# 14                    False                 False                 False
# 15                     True                 False                 False
# ...                     ...                   ...                   ...
# 19663                 False                 False                 False
# 19664                 False                 False                 False
# 19665                 False                 False                 False
# 19666                 False                 False                 False
# 19667                 False                 False                 False
#
#        label_full_tests_needed  label_kind_bug  label_kind_documentation  \
# 0                        False           False                     False
# 2                        False           False                      True
# 10                       False           False                     False
# 14                       False           False                      True
# 15                       False           False                     False
# ...                        ...             ...                       ...
# 19663                    False           False                     False
# 19664                    False           False                     False
# 19665                    False           False                     False
# 19666                    False           False                     False
# 19667                    False           False                     False
#
#        label_kind_feature  label_okay_to_merge  label_provider_Google  \
# 0                   False                 True                  False
# 2                   False                 True                  False
# 10                  False                 True                  False
# 14                  False                False                  False
# 15                  False                False                  False
# ...                   ...                  ...                    ...
# 19663               False                False                  False
# 19664               False                False                  False
# 19665               False                False                  False
# 19666               False                False                  False
# 19667               False                False                  False
#
#        frequent_issue_creator  outlier
# 0                       False     True
# 2                        True     True
# 10                       True     True
# 14                      False     True
# 15                       True     True
# ...                       ...      ...
# 19663                   False     True
# 19664                   False     True
# 19665                   False     True
# 19666                    True     True
# 19667                    True     True
#
# [17755 rows x 33 columns]

# %%
df_ml.time_to_close.hist(bins=5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The distribution of tickets is exponential and right skewed. Although arbitrary, I'm going to bin the values.
#
# Days:
#
# * 0 to 1
# * 1 to 3
# * 3 to 5
# * 5+

# %%
df_ml.time_to_close.value_counts()
# Out:
# 0      6523
# 1      2881
# 2      1115
# 3       696
# 4       516
#        ...
# 343       1
# 304       1
# 366       1
# 399       1
# 246       1
# Name: time_to_close, Length: 426, dtype: int64

# %%
def binning(x):
    if x < 1:
        return 'Less than 1 day'
    elif x >= 1 and x <= 3:
        return '1-3 days'
    elif x > 3 and x <= 5:
        return '3-5 days'
    else:
        return 'More than 5 days'

# %%
df_ml['time_to_complete'] = df_ml.time_to_close.apply(lambda x: binning(x))

# %%
df_ml
# Out:
#       creator_user_login creator_user_id  \
# 0             vinitpayal        10959000
# 2                 potiuk          595491
# 10                 kaxil         8811558
# 14           gontcharovd        49554133
# 15             subkanthi        17434846
# ...                  ...             ...
# 19663            eerwitt         1329385
# 19664            eerwitt         1329385
# 19665            osallou         1024098
# 19666       mistercrunch          487433
# 19667       mistercrunch          487433
#
#                                                    title   state  comments  \
# 0                            Rename amazon EMR hook name  closed         3
# 2      Add documentation for an ad-hoc release of 2 p...  closed         1
# 10     Bugfix: ``SFTPHook`` does not respect ``ssh_co...  closed         1
# 14                          Update manage-dags-files.rst  closed         2
# 15         Update python version to 3.7 contributing.rst  closed         0
# ...                                                  ...     ...       ...
# 19663                              Misc spelling updates  closed         3
# 19664                              setup.py download URL  closed         3
# 19665     Can't add external executors -> Plugin manager  closed        17
# 19666              Bring in more resolution to hivestats  closed         0
# 19667  Improving the search functionality in the grap...  closed         0
#
#       created_date closed_date  time_to_close                created_at  \
# 0       2022-01-08  2022-01-08              0 2022-01-08 14:15:31+00:00
# 2       2022-01-08  2022-01-08              0 2022-01-08 11:24:41+00:00
# 10      2022-01-07  2022-01-07              0 2022-01-07 19:00:53+00:00
# 14      2022-01-07  2022-01-07              0 2022-01-07 15:27:48+00:00
# 15      2022-01-07  2022-01-07              0 2022-01-07 15:04:26+00:00
# ...            ...         ...            ...                       ...
# 19663   2015-06-05  2015-06-07              2 2015-06-05 17:50:46+00:00
# 19664   2015-06-05  2015-06-05              0 2015-06-05 15:18:52+00:00
# 19665   2015-06-05  2015-06-17             12 2015-06-05 14:28:38+00:00
# 19666   2015-04-20  2015-04-20              0 2015-04-20 21:54:45+00:00
# 19667   2015-04-20  2015-04-20              0 2015-04-20 21:52:31+00:00
#
#                       closed_at author_association  \
# 0     2022-01-08 15:26:09+00:00        CONTRIBUTOR
# 2     2022-01-08 13:59:11+00:00             MEMBER
# 10    2022-01-07 21:00:17+00:00             MEMBER
# 14    2022-01-07 15:32:13+00:00               NONE
# 15    2022-01-07 15:10:21+00:00        CONTRIBUTOR
# ...                         ...                ...
# 19663 2015-06-07 07:55:22+00:00        CONTRIBUTOR
# 19664 2015-06-05 17:24:57+00:00        CONTRIBUTOR
# 19665 2015-06-17 15:41:31+00:00               NONE
# 19666 2015-04-20 22:58:48+00:00             MEMBER
# 19667 2015-04-20 21:52:33+00:00             MEMBER
#
#                                                     body  has_pull_request  \
# 0      Renamed emr hook from Elastic MapReduce to Ama...              True
# 2      <!--\r\nThank you for contributing! Please mak...              True
# 10     closes https://github.com/apache/airflow/issue...              True
# 14     Running `base64 <my-private-ssh-key> -w 0 > te...              True
# 15     Since 3.6 is no longer supported, updated mini...              True
# ...                                                  ...               ...
# 19663  I was reading over the code to understand how ...              True
# 19664  While installing I noticed the `url` and `down...             False
# 19665  Would be nice to be able to add other executor...             False
# 19666                                                                 True
# 19667                                                                 True
#
#        has_comment  has_assignee  contributor  member  collaborator  \
# 0             True         False         True   False         False
# 2             True         False        False    True         False
# 10            True         False        False    True         False
# 14            True         False        False   False         False
# 15           False         False         True   False         False
# ...            ...           ...          ...     ...           ...
# 19663         True         False         True   False         False
# 19664         True         False         True   False         False
# 19665         True         False        False   False         False
# 19666        False         False        False    True         False
# 19667        False         False        False    True         False
#
#        not_a_member  length_of_title  length_of_body  n_labels  \
# 0             False               27            1266         3
# 2             False               54            1072         4
# 10            False               57            1129         3
# 14             True               28             133         2
# 15            False               45            1160         1
# ...             ...              ...             ...       ...
# 19663         False               21             282         0
# 19664         False               21             401         0
# 19665          True               46             203         0
# 19666         False               37               0         0
# 19667         False               52               0         0
#
#        label_area_dev_tools  label_area_providers  label_area_webserver  \
# 0                     False                  True                 False
# 2                     False                  True                 False
# 10                    False                  True                 False
# 14                    False                 False                 False
# 15                     True                 False                 False
# ...                     ...                   ...                   ...
# 19663                 False                 False                 False
# 19664                 False                 False                 False
# 19665                 False                 False                 False
# 19666                 False                 False                 False
# 19667                 False                 False                 False
#
#        label_full_tests_needed  label_kind_bug  label_kind_documentation  \
# 0                        False           False                     False
# 2                        False           False                      True
# 10                       False           False                     False
# 14                       False           False                      True
# 15                       False           False                     False
# ...                        ...             ...                       ...
# 19663                    False           False                     False
# 19664                    False           False                     False
# 19665                    False           False                     False
# 19666                    False           False                     False
# 19667                    False           False                     False
#
#        label_kind_feature  label_okay_to_merge  label_provider_Google  \
# 0                   False                 True                  False
# 2                   False                 True                  False
# 10                  False                 True                  False
# 14                  False                False                  False
# 15                  False                False                  False
# ...                   ...                  ...                    ...
# 19663               False                False                  False
# 19664               False                False                  False
# 19665               False                False                  False
# 19666               False                False                  False
# 19667               False                False                  False
#
#        frequent_issue_creator  outlier  time_to_complete
# 0                       False     True   Less than 1 day
# 2                        True     True   Less than 1 day
# 10                       True     True   Less than 1 day
# 14                      False     True   Less than 1 day
# 15                       True     True   Less than 1 day
# ...                       ...      ...               ...
# 19663                   False     True          1-3 days
# 19664                   False     True   Less than 1 day
# 19665                   False     True  More than 5 days
# 19666                    True     True   Less than 1 day
# 19667                    True     True   Less than 1 day
#
# [17755 rows x 34 columns]

# %% [markdown]
# ### Let's move onto feature selection

# %%
'''
Which of the features above should we include in our ML model?

The title and body are great text features which we could do some NLP on, but maybe later.
'''
def split_features_and_target(df, features_ml=None):
    target = df.time_to_complete
    df.drop([c for c in df if c not in features_ml], axis=1, inplace=True)
    return df, target


features_ml, target = split_features_and_target(
    df_ml,
    features_ml = [
        # 'comments',
        # 'has_pull_request', 	
        # 'has_comment', 	
        'has_assignee', 	
        'length_of_title', 	
        'length_of_body', 	
        'n_labels', 	
        'label_area_dev_tools', 	
        'label_area_providers', 	
        'label_area_webserver', 	
        'label_full_tests_needed', 	
        'label_kind_bug', 	
        'label_kind_documentation', 	
        'label_kind_feature', 	
        'label_okay_to_merge', 	
        'label_provider_Google',	
        'frequent_issue_creator',
        'contributor',
        'member',
        'collaborator',
        'not_a_member'
    ]
)

features_ml
# Out:
#        has_assignee  contributor  member  collaborator  not_a_member  \
# 0             False         True   False         False         False
# 2             False        False    True         False         False
# 10            False        False    True         False         False
# 14            False        False   False         False          True
# 15            False         True   False         False         False
# ...             ...          ...     ...           ...           ...
# 19663         False         True   False         False         False
# 19664         False         True   False         False         False
# 19665         False        False   False         False          True
# 19666         False        False    True         False         False
# 19667         False        False    True         False         False
#
#        length_of_title  length_of_body  n_labels  label_area_dev_tools  \
# 0                   27            1266         3                 False
# 2                   54            1072         4                 False
# 10                  57            1129         3                 False
# 14                  28             133         2                 False
# 15                  45            1160         1                  True
# ...                ...             ...       ...                   ...
# 19663               21             282         0                 False
# 19664               21             401         0                 False
# 19665               46             203         0                 False
# 19666               37               0         0                 False
# 19667               52               0         0                 False
#
#        label_area_providers  label_area_webserver  label_full_tests_needed  \
# 0                      True                 False                    False
# 2                      True                 False                    False
# 10                     True                 False                    False
# 14                    False                 False                    False
# 15                    False                 False                    False
# ...                     ...                   ...                      ...
# 19663                 False                 False                    False
# 19664                 False                 False                    False
# 19665                 False                 False                    False
# 19666                 False                 False                    False
# 19667                 False                 False                    False
#
#        label_kind_bug  label_kind_documentation  label_kind_feature  \
# 0               False                     False               False
# 2               False                      True               False
# 10              False                     False               False
# 14              False                      True               False
# 15              False                     False               False
# ...               ...                       ...                 ...
# 19663           False                     False               False
# 19664           False                     False               False
# 19665           False                     False               False
# 19666           False                     False               False
# 19667           False                     False               False
#
#        label_okay_to_merge  label_provider_Google  frequent_issue_creator
# 0                     True                  False                   False
# 2                     True                  False                    True
# 10                    True                  False                    True
# 14                   False                  False                   False
# 15                   False                  False                    True
# ...                    ...                    ...                     ...
# 19663                False                  False                   False
# 19664                False                  False                   False
# 19665                False                  False                   False
# 19666                False                  False                    True
# 19667                False                  False                    True
#
# [17755 rows x 18 columns]

# %%
target.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Classification

# %%
# Split the data for training and testing
x_train, x_test, y_train, y_test = train_test_split(features_ml, target, random_state = 0)

# %% [markdown]
# #### K-Nearest Neighbors - No Scaling

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[410  27 478 268]
#  [ 91   2  86  60]
#  [453  30 794 301]
#  [466  23 499 451]]
#                   precision    recall  f1-score   support
#
#         1-3 days       0.29      0.35      0.32      1183
#         3-5 days       0.02      0.01      0.01       239
#  Less than 1 day       0.43      0.50      0.46      1578
# More than 5 days       0.42      0.31      0.36      1439
#
#         accuracy                           0.37      4439
#        macro avg       0.29      0.29      0.29      4439
#     weighted avg       0.37      0.37      0.37      4439

# %% [markdown]
# #### K-Nearest Neighbors - StandardScaler Scaling

# %%
''' 
Going to do some feature scaling and normalize the data
StandardScaler works by calculating the z-score for each value within a column
For the majority of these values, we're dealing with binary (T/F) values
StandardScaler automatically converts the string values into 1 or 0 (T/F, respectively) and applies the z-score transformation for that respective column.
'''
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)

x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(x_test_scaled)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[405  35 484 259]
#  [ 76  14  88  61]
#  [478  15 871 214]
#  [377  28 322 712]]
#                   precision    recall  f1-score   support
#
#         1-3 days       0.30      0.34      0.32      1183
#         3-5 days       0.15      0.06      0.08       239
#  Less than 1 day       0.49      0.55      0.52      1578
# More than 5 days       0.57      0.49      0.53      1439
#
#         accuracy                           0.45      4439
#        macro avg       0.38      0.36      0.36      4439
#     weighted avg       0.45      0.45      0.45      4439

# %% [markdown]
# #### Decision Tree Classifier

# %%
# Split the data for training and testing
x_train, x_test, y_train, y_test = train_test_split(features_ml, target, random_state = 0)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier_decision_tree = DecisionTreeClassifier()
classifier_decision_tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = classifier_decision_tree.predict(x_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[346  73 436 328]
#  [ 66  20  81  72]
#  [435  78 750 315]
#  [333  84 343 679]]
#                   precision    recall  f1-score   support
#
#         1-3 days       0.29      0.29      0.29      1183
#         3-5 days       0.08      0.08      0.08       239
#  Less than 1 day       0.47      0.48      0.47      1578
# More than 5 days       0.49      0.47      0.48      1439
#
#         accuracy                           0.40      4439
#        macro avg       0.33      0.33      0.33      4439
#     weighted avg       0.41      0.40      0.41      4439

# %%
scaler = StandardScaler()
scaler.fit(x_train)

x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)
